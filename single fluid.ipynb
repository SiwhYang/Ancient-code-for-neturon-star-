# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib notebook 

s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77
MxC = 50


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listrho = []
listxp = []
rho = 0
while rho < 1.2:
    def F(xp):
        en_s = s_a*rho + s_b*rho**s_r
        en_n = n_a*rho + n_b*rho**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*rho*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    listrho.append(rho)
    listxp.append(xp)
    rho = rho + 0.01

plt.plot(listrho,listxp,label="NO DM")

################################################# DM
listrho = []
listxp = []
rho = 0
while rho < 1.2:
    def F(xp):
        en_s = s_a*rho + s_b*rho**s_r
        en_n = n_a*rho + n_b*rho**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*rho*xp) - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) \
        - ( np.heaviside(Ha-MxC ,0) * ((Ha**2-MxC**2)**(3/2)) )
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    listrho.append(rho)
    listxp.append(xp)
    rho = rho + 0.01


plt.plot(listrho,listxp,label="DM")

plt.title("Proton Fraction")
plt.legend(loc='upper right')

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib notebook 

s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77
MxC = 50


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listrho = []
listxp = []
rho = 0
while rho < 1.2:
    def F(xp):
        en_s = s_a*rho + s_b*rho**s_r
        en_n = n_a*rho + n_b*rho**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*rho*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    listrho.append(rho)
    listxp.append(xp)
    rho = rho + 0.01

plt.plot(listrho,listxp,label="Mu")
plt.legend(loc='upper right')



s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77
MxC = 50


MmuC =0.0000000000001
pi = 3.14
c = 2.99792458
hc = 197.33

listrho = []
listxp = []
rho = 0
while rho < 1.2:
    def F(xp):
        en_s = s_a*rho + s_b*rho**s_r
        en_n = n_a*rho + n_b*rho**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*rho*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    listrho.append(rho)
    listxp.append(xp)
    rho = rho + 0.01

plt.plot(listrho,listxp,label="change Mu")
plt.legend(loc='upper right')

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib notebook 
from numpy import diff

s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77
MxC = 50


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]

nb = 0
while nb < 2.0:
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))**(delta**2))
            
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


listP = [i * 1.6022e33 for i in listP] 
listrho = [i *(1.7827e12)* 931.494 for i in listnb] 
#plt.plot(listnb,listxp,label=' fraction')
#plt.plot(listnb,listE,label=' Energy')
plt.plot(listrho,listP,label=' Pressure')

'''
plt.plot(listnb,listen_s,label='en_s')
plt.plot(listnb,listen_n,label='en_n')
plt.plot(listnb,listEsym,label='Esym')
'''

plt.legend(loc='upper right')
plt.yscale('log')
#plt.xscale('log')

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff

s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77
MxC = 50


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]

nb = 0
while nb < 1.2:
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))**(delta**2))
            
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


listP = [i * 1.6022e33 for i in listP] 
listrho = [i *(1.7827e12)* 931.494 for i in listnb] 


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.67428e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    #dPdr = -G*(rho(P) + P/c**2)*(m + 4.0*pi*r**3*P/c**2)
    #dPdr = dPdr/(r*(r - 2.0*G*m/c**2))
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol[:,0] 

r = np.arange(10,5000000,1)

#plot M_R curve
r = np.arange(10,20000,0.01).reshape(1999000,1)
#rhoc = np.logspace(15.5,15.55)
rhoc = np.arange(5e14,3e15,1e14)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    M[i] = max(TOVsolve(rhoc[i]))
    location = np.where(TOVsolve(rhoc[i])== M[i])
    R[i] = r[location]
    i = i + 1
    
# max M and R
M_max = max(M)
location1 = np.where(M == M_max)
R_max = R[location1]


print("Max mass :",M_max/Msun)
print("Max mass radius :" ,R_max/1000)
plt.plot(R/1000,M/Msun,label='DM')
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
plt.xlim(5,15)
plt.show
'''
Msun = 1.98892e33

rhoc = 5.00e+13
#plt.plot(r,TOVsolve(rhoc)/Msun)
plt.plot(r/10000,TOVsolve(rhoc))
diff = (np.diff(TOVsolve(rhoc)) )/( np.diff(r) )

print(diff)
'''

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib notebook 
from numpy import diff

'''
#Bonn B + MICRO (G)
s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77

#V18+UIX (K)
s_a = -265.5
s_b = 406.6
s_r = 1.47
n_a = 77.1
n_b = 257.4
n_r = 2.27
'''
#Nij93 + MICRO (G)
s_a = -152.5
s_b = 343.3
s_r = 1.94
n_a = 72.3
n_b = 693.6
n_r = 2.67



MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]

nb = 0
while nb < 2.0:
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))**(delta**2))
            
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


listP = [i * 1.6022e33 for i in listP] 
listrho = [i *(1.7827e12)* 931.494 for i in listnb] 


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    #dPdr = -G*(rho(P) + P/c**2)*(m + 4.0*pi*r**3*P/c**2)
    #dPdr = dPdr/(r*(r - 2.0*G*m/c**2))
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol[:,1] 

r = np.arange(10,5000000,1)

#plot M_R curve
#rhoc =np.logspace(13.5,24.5,1000) #(3e16,4e16,5e16,5e17,5e18,5e19)
rhoc =np.logspace(13.5,16,50) 
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    diff = np.diff(TOVsolve(rhoc[i])) / np.diff(r)
    lo = np.where (diff == 0)[0]
    location = lo[0]
    M[i] = TOVsolve(rhoc[i])[location]
    R[i] = r[location]
    i = i +1
    
Msun = 1.98892e33
plt.scatter(R/100000,M/Msun)
plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')


plt.ylim(0,3)
plt.xlim(5,15)

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
#matplotlib notebook 
from numpy import diff

#24.5
p = 500
'''
#Bonn B + MICRO (G)
s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77

#V18+UIX (K)
s_a = -265.5
s_b = 406.6
s_r = 1.47
n_a = 77.1
n_b = 257.4
n_r = 2.27
'''
#Nij93 + MICRO (G)
s_a = -152.5
s_b = 343.3
s_r = 1.94
n_a = 72.3
n_b = 693.6
n_r = 2.67



MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]

nb = 0
while nb < 2.0:
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))**(delta**2))
            
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


listP = [i * 1.6022e33 for i in listP] 
listrho = [i *(1.7827e12)* 931.494 for i in listnb] 


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    #dPdr = -G*(rho(P) + P/c**2)*(m + 4.0*pi*r**3*P/c**2)
    #dPdr = dPdr/(r*(r - 2.0*G*m/c**2))
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol[:,1] 

r = np.arange(10,5000000,1)

#plot M_R curve
rhoc =np.logspace(13.5,24.5,p) #(3e16,4e16,5e16,5e17,5e18,5e19)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    diff = np.diff(TOVsolve(rhoc[i])) / np.diff(r)
    lo = np.where (diff == 0)[0]
    location = lo[0]
    M[i] = TOVsolve(rhoc[i])[location]
    R[i] = r[location]
    i = i +1
    
Msun = 1.9891e33
plt.scatter(R/100000,M/Msun,label='Nij93 + MICRO (G)' , s = 10)
plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')


plt.ylim(0,3)
plt.xlim(5,15)

####################################################

#V18+UIX (K)
s_a = -265.5
s_b = 406.6
s_r = 1.47
n_a = 77.1
n_b = 257.4
n_r = 2.27




MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]

nb = 0
while nb < 2.0:
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))**(delta**2))
            
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


listP = [i * 1.6022e33 for i in listP] 
listrho = [i *(1.7827e12)* 931.494 for i in listnb] 


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    #dPdr = -G*(rho(P) + P/c**2)*(m + 4.0*pi*r**3*P/c**2)
    #dPdr = dPdr/(r*(r - 2.0*G*m/c**2))
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol[:,1] 

r = np.arange(10,5000000,1)

#plot M_R curve
rhoc =np.logspace(13.5,24.5,p) #(3e16,4e16,5e16,5e17,5e18,5e19)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    diff = np.diff(TOVsolve(rhoc[i])) / np.diff(r)
    lo = np.where (diff == 0)[0]
    location = lo[0]
    M[i] = TOVsolve(rhoc[i])[location]
    R[i] = r[location]
    i = i +1
    
Msun = 1.9891e33
plt.scatter(R/100000,M/Msun,label='V18+UIX (K)' , s = 10)
plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')


plt.ylim(0,3)
plt.xlim(5,15)

#####################
#V18+UIX (G)
s_a = -425.5
s_b = 556
s_r = 1.24
n_a = 78
n_b = 232.9
n_r = 2.24




MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]

nb = 0
while nb < 2.0:
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))**(delta**2))
            
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


listP = [i * 1.6022e33 for i in listP] 
listrho = [i *(1.7827e12)* 931.494 for i in listnb] 


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    #dPdr = -G*(rho(P) + P/c**2)*(m + 4.0*pi*r**3*P/c**2)
    #dPdr = dPdr/(r*(r - 2.0*G*m/c**2))
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol[:,1] 

r = np.arange(10,5000000,1)

#plot M_R curve
rhoc =np.logspace(13.5,24.5,p) #(3e16,4e16,5e16,5e17,5e18,5e19)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    diff = np.diff(TOVsolve(rhoc[i])) / np.diff(r)
    lo = np.where (diff == 0)[0]
    location = lo[0]
    M[i] = TOVsolve(rhoc[i])[location]
    R[i] = r[location]
    i = i +1
    
Msun = 1.9891e33
plt.scatter(R/100000,M/Msun,label='V18+UIX (G)' , s = 10)
plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')


plt.ylim(0,3)
plt.xlim(5,15)




#CD Bonn + UIX(K)
s_a = -306.5
s_b = 424
s_r = 1.38
n_a = 87.3
n_b = 175
n_r = 2.33




MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]

nb = 0
while nb < 2.0:
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3 \
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) )  
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))**(delta**2))
            
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


listP = [i * 1.6022e33 for i in listP] 
listrho = [i *(1.7827e12)* 931.494 for i in listnb] 


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    #dPdr = -G*(rho(P) + P/c**2)*(m + 4.0*pi*r**3*P/c**2)
    #dPdr = dPdr/(r*(r - 2.0*G*m/c**2))
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol[:,1] 

r = np.arange(10,5000000,1)

#plot M_R curve
rhoc =np.logspace(13.5,24.5,p) #(3e16,4e16,5e16,5e17,5e18,5e19)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    diff = np.diff(TOVsolve(rhoc[i])) / np.diff(r)
    lo = np.where (diff == 0)[0]
    location = lo[0]
    M[i] = TOVsolve(rhoc[i])[location]
    R[i] = r[location]
    i = i +1
    
Msun = 1.9891e33
plt.scatter(R/100000,M/Msun,label='CD Bonn + UIX(K)' , s = 10)
plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
plt.legend(loc='upper right')
plt.ylim(0,3)
plt.xlim(5,15)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\optimize\zeros.py:287: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = _zeros._bisect(f,a,b,xtol,rtol,maxiter,args,full_output,disp)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-2b05013a22e1> in <module>()
#     132     lo = np.where (diff == 0)[0]
#     133     location = lo[0]
# --> 134     M[i] = TOVsolve(rhoc[i])[location]
#     135     R[i] = r[location]
#     136     i = i +1
#
# <ipython-input-16-2b05013a22e1> in TOVsolve(rhoc)
#     118     m = 4.0*pi*r[0]**3*rhoc
#     119     P = eos(rhoc)
# --> 120     psol = odeint(TOV,[P,m],r)
#     121     return  psol[:,1]
#     122
#
# ~\Anaconda3\lib\site-packages\scipy\integrate\odepack.py in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     231                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     232                              ixpr, mxstep, mxhnil, mxordn, mxords,
# --> 233                              int(bool(tfirst)))
#     234     if output[-1] < 0:
#     235         warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# <ipython-input-16-2b05013a22e1> in TOV(y, r)
#     111     #dPdr = dPdr/(r*(r - 2.0*G*m/c**2))
#     112     dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )
# --> 113     dmdr = 4.0*pi*r**2*rho(P)
#     114     return np.array([dPdr, dmdr])
#     115
#
# ~\Anaconda3\lib\site-packages\scipy\interpolate\polyint.py in __call__(self, x)
#      77         """
#      78         x, x_shape = self._prepare_x(x)
# ---> 79         y = self._evaluate(x)
#      80         return self._finish_y(y, x_shape)
#      81
#
# ~\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py in _evaluate(self, x_new)
#     660         #    The behavior is set by the bounds_error variable.
#     661         x_new = asarray(x_new)
# --> 662         y_new = self._call(self, x_new)
#     663         if not self._extrapolate:
#     664             below_bounds, above_bounds = self._check_bounds(x_new)
#
# ~\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py in _call_linear(self, x_new)
#     595         #    self.x indices and at least 1.  Removes mis-interpolation
#     596         #    of x_new[n] = x[0]
# --> 597         x_new_indices = x_new_indices.clip(1, len(self.x)-1).astype(int)
#     598
#     599         # 4. Calculate the slope of regions that each x_new value falls in.
#
# KeyboardInterrupt:

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff

p = 1
m = 9.1e-28


s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77

MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    mn =  931.494 
    rho = nb*(E+mn)
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listnp.append(nproton)
    listx.append(x)
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] + pre(listx)
listrho =   [i *(1.7827e12)* 931.494 for i in listnb] + e(listx)



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)



#plot M_R curve
rhoc =np.logspace(13.8,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    
Msun = 2e33
plt.plot(R/100000,M/Msun,label='Bonn B + MICRO (G)')
#plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')


plt.ylim(0,3)
plt.xlim(5,15)




########################################################
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff


m = 9.1e-28


#V18+ MICRO (G)
s_a = -123.2
s_b = 407.9
s_r = 2.38
n_a = 55.9
n_b = 532.3
n_r = 2.68


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listnp.append(nproton)
    listx.append(x)
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] + pre(listx)
listrho =   [i *(1.7827e12)* 931.494 for i in listnb] + e(listx)



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)


#plot M_R curve
rhoc =np.logspace(13.8,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    
Msun = 1.9891e33
plt.plot(R/100000,M/Msun,label='V18+ MICRO (G)' , linestyle = '--')
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
plt.ylim(0,3)
plt.xlim(5,15)




######################################


import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff


m = 9.1e-28


#Nij93 + MICRO (G)
s_a = -152.5
s_b = 343.3
s_r = 1.94
n_a = 72.3
n_b = 693.6
n_r = 2.67


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listnp.append(nproton)
    listx.append(x)
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] + pre(listx)
listrho =   [i *(1.7827e12)* 931.494 for i in listnb] + e(listx)



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)


#plot M_R curve
rhoc =np.logspace(14.0,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    
Msun = 1.9891e33
plt.plot(R/100000,M/Msun,label='Nij93 + MICRO (G)' , linestyle = '-.')
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
plt.ylim(0,3)
plt.xlim(5,15)






###############################################

m = 9.1e-28


#CD Bonn + UIX(K)
s_a = -306.5
s_b = 424
s_r = 1.38
n_a = 87.3
n_b = 175
n_r = 2.33

MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listnp.append(nproton)
    listx.append(x)
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] + pre(listx)
listrho =   [i *(1.7827e12)* 931.494 for i in listnb] + e(listx)



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)



#plot M_R curve
rhoc =np.logspace(14.0,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    

Msun = 2e33
plt.plot(R/100000,M/Msun,label='CD Bonn + UIX(K)' , linestyle = ':')
#plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
plt.legend(loc='lower left')
plt.ylim(0,3)
plt.xlim(0,18)

plt.savefig('filename4562156789.png',dpi=300)
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\optimize\zeros.py:287: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = _zeros._bisect(f,a,b,xtol,rtol,maxiter,args,full_output,disp)

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff

p = 50
me = 9.1e-28
mmu = 1.18e-25

s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77

MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listxe = []
listxmu = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    
    c = 2.998e10
    nproton_cm = nb*xp*1e39 *0.5
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    xe = k/(me*c)
    xmu = k/(mmu*c)
    listxe.append(xe)
    listxmu.append(xmu)
    
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
    

def e(x,m) :
    e0 = m**4*c**5/(pi**2*h**3)
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x,m):
    e0 = m**4*c**5/(pi**2*h**3)
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


listxe = np.asarray(listxe)
listxmu = np.asarray(listxmu)
mmu = np.asarray ([mmu] * len(listxmu))
me = np.asarray ([me] * len(listxe))


listP =  [i * 1.6022e33 for i in listP]+ pre(listxe,me) + pre(listxmu,mmu)
listrho =   [i *(1.7827e12)* 931.494 for i in listnb]  + e(listxe,me) + e(listxmu,mmu)



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)



#plot M_R curve
rhoc =np.logspace(13.8,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    
Msun = 2e33
plt.plot(R/100000,M/Msun,label='Bonn B + MICRO (G)')
#plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')


plt.ylim(0,3)
plt.xlim(0,15)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\optimize\zeros.py:287: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = _zeros._bisect(f,a,b,xtol,rtol,maxiter,args,full_output,disp)
# (0, 15)

# %%
plt.plot(e(listxmu,mmu) , pre(listxmu,mmu))
plt.plot (e(listxe,me) ,pre(listxe,me))

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff

p = 150
m = 9.1e-28
h = 1.0545716e-27

s_a = -130.4
s_b = 537
s_r = 2.39
n_a = 31.0
n_b = 780.2
n_r = 2.77

MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []
listrho = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    mn =  931.494 
    rho = nb*(E+mn)
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listx.append(x)
    listrho.append(rho)
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] + pre(listx)
listrho =   [i *(1.7827e12) for i in listrho] + e(listx)



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)



#plot M_R curve
rhoc =np.logspace(13.8,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    
Msun = 2e33
#plt.plot(R/100000,M/Msun,label='Bonn B')
#plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')


plt.ylim(0,3)
plt.xlim(5,15)




########################################################
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff


m = 9.1e-28


#V18+ MICRO (G)
s_a = -123.2
s_b = 407.9
s_r = 2.38
n_a = 55.9
n_b = 532.3
n_r = 2.68


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []
listrho = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    mn =  931.494 
    rho = nb*(E+mn)
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)

    listx.append(x)
    listrho.append(rho)
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] + pre(listx)
listrho =   [i *(1.7827e12) for i in listrho] #+ e(listx)


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)


#plot M_R curve
rhoc =np.logspace(13.8,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    
Msun = 1.9e33
plt.plot(R/100000,M/Msun,label='V18' , linestyle = '--')
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
plt.ylim(0,3)
plt.xlim(5,15)




######################################


import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff


m = 9.1e-28


#Nij93 + MICRO (G)
s_a = -152.5
s_b = 343.3
s_r = 1.94
n_a = 72.3
n_b = 693.6
n_r = 2.67


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []
listrho = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    mn =  931.494 
    rho = nb*(E+mn)
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listx.append(x)
    
    listrho.append(rho)
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] + pre(listx)
listrho =   [i *(1.7827e12) for i in listrho] #+ e(listx)


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)


#plot M_R curve
rhoc =np.logspace(14.0,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    
Msun = 1.9e33
plt.plot(R/100000,M/Msun,label='N93 ' , linestyle = '-.')
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
plt.ylim(0,3)
plt.xlim(5,15)






###############################################

m = 9.1e-28


#CD Bonn + UIX(K)
s_a = -452.5
s_b = 556.0
s_r = 1.24
n_a = 78
n_b = 232.9
n_r = 2.24

MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []
listrho = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    mn =  931.494 
    rho = nb*(E+mn)
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listx.append(x)
    
    listrho.append(rho)
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] + pre(listx)
listrho =   [i *(1.7827e12) for i in listrho] #+ e(listx)



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)



#plot M_R curve
rhoc =np.logspace(14.0,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    

Msun = 1.9e33
plt.plot(R/100000,M/Msun,label='UIX' , linestyle = ':')
#plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
#plt.legend(loc='lower left')
plt.legend(loc='upper right')
plt.ylim(0,2.5)
plt.xlim(6,18)

plt.savefig('filename4562156789.png',dpi=300)
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\optimize\zeros.py:287: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = _zeros._bisect(f,a,b,xtol,rtol,maxiter,args,full_output,disp)

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff

p = 15
m = 9.1e-28
h = 1.0545716e-27


########################################################
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff


m = 9.1e-28




######################################


import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff


m = 9.1e-28


#Nij93 + MICRO (G)
s_a = -152.5
s_b = 343.3
s_r = 1.94
n_a = 72.3
n_b = 693.6
n_r = 2.67


MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []
listrho = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    mn =  931.494 
    rho = nb*(E+mn)
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listx.append(x)
    
    listrho.append(rho)
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] #+ pre(listx)
listrho =   [i *(1.7827e12) for i in listrho] #+ e(listx)


from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)


#plot M_R curve
rhoc =np.logspace(14.0,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    
Msun = 1.9e33
plt.plot(R/100000,M/Msun,label='N93 ' , linestyle = '-.')
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
plt.ylim(0,3)
plt.xlim(5,15)






###############################################

m = 9.1e-28


#CD Bonn + UIX(K)
s_a = -452.5
s_b = 556.0
s_r = 1.24
n_a = 78
n_b = 232.9
n_r = 2.24

MmuC = 105.6
pi = 3.14
c = 2.99792458
hc = 197.33

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []
listrho = []

nb = 0.00
while nb < 2.0:
    MmuC = 105.6
    pi = 3.14
    c = 2.99792458
    hc = 197.33
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = (3*pi**2*hc**3*nb*xp)  - Ha**3\
        - ( np.heaviside(Ha-MmuC ,0) * ((Ha**2-MmuC**2)**(3/2)) ) 
        return Sol
    xp = scipy.optimize.bisect(F,0,2)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (s_a + s_r* s_b*nb**(s_r-1) + ( n_a + n_r * n_b*nb**(n_r-1) - s_a - s_r* s_b*nb**(s_r-1))*(delta)**2)
    mn =  931.494 
    rho = nb*(E+mn)
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listx.append(x)
    
    listrho.append(rho)
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] #+ pre(listx)
listrho =   [i *(1.7827e12) for i in listrho] 



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)



#plot M_R curve
rhoc =np.logspace(14.0,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    

Msun = 1.9e33
plt.plot(R/100000,M/Msun,label='UIX' , linestyle = ':')
#plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
#plt.legend(loc='lower left')
plt.legend(loc='upper right')
plt.ylim(0,2.5)
plt.xlim(6,18)

#plt.savefig('filename4562156789.png',dpi=300)
plt.show()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\scipy\optimize\zeros.py:287: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = _zeros._bisect(f,a,b,xtol,rtol,maxiter,args,full_output,disp)

# %%
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff

p = 15
m = 9.1e-28
h = 1.0545716e-27


########################################################
import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff


m = 9.1e-28




######################################


import numpy as np
from scipy.optimize import curve_fit
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from numpy import diff


m = 9.1e-28

s_a = -425.5
s_b = 556.0
s_r = 1.24
n_a = 78
n_b = 232.9
n_r = 2.24


MmuC = 105.6
pi = 3.14
hc = 197

listnb = []
listxp = []
listepsilon = []
listE = []
listP = []
listdelta = []



listen_s=[]
listen_n=[]
listEsym=[]
listx = []
listk = []
listnp = []
listx = []
listrho = []

nb = 0.1
while nb < 1.0:
    MmuC = 105.6
    pi = 3.14
    hc = 197
    def F(xp):
        en_s = s_a*nb + s_b*nb**s_r
        en_n = n_a*nb + n_b*nb**n_r
        Esym = en_n - en_s
        Ha = 4*Esym*(1-2*xp)
        Sol = ((3*pi**2)*(hc**3)*nb*xp)  - Ha**3
        return Sol
    xp = scipy.optimize.bisect(F,0,1)
    
    en_s = s_a*nb + s_b*nb**s_r
    en_n = n_a*nb + n_b*nb**n_r
    en_s_prime = s_a + s_r * s_b*nb**(s_r-1)
    en_n_prime = n_a + n_r * n_b*nb**(n_r-1)            
    Esym =  en_n - en_s 
    
    
    delta = 1 - 2*xp
    E = en_n + Esym*delta**2
    P = (nb**2)* (en_n + en_n - en_s - 4*xp*(en_n_prime-en_s_prime) + 4 * (xp/nb)*( en_n - en_s)  \
                 + 4 *xp**2*(en_n_prime-en_s_prime) - 8 *((xp**2)/nb) * ( en_n - en_s)  )
    
    
    #P = (nb**2) * (en_n_prime + (1-2*xp)**2* (en_n_prime-en_s_prime))
    mn =  931.494 
    rho = nb*(E+mn)
    c = 3e10
    nproton_cm = nb*xp*1e39
    k = (3*pi**2*h**3*nproton_cm)**(1/3)
    x = k/(m*c)
    listx.append(x)
    
    listrho.append(rho)
    listen_s.append(en_s)
    listen_n.append(en_n)
    listEsym.append(Esym)
    listdelta.append(delta)
    listP.append(P)
    listE.append(E)
    listnb.append(nb)
    listxp.append(xp)
    nb = nb + 0.001


#plt.plot(listnb,listP)
#plt.ylim(1,1000)



c = 2.998e10
pi = 3.14159265359
G = 6.67428e-8
h = 1.0545716e-27
e0 = m**4*c**5/(pi**2*h**3)
    
    

def e(x) :
    return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2)) -  np.arcsinh(x)) /c**2
    #return (e0/8) *(  ((2*x**3 + x) * (1 + x**2)**(1/2))      -  np.log( x + ((1 + x**2)**(1/2))    )) /c**2
def pre(x):
    return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2)) + 3*np.arcsinh(x)    )
     #return (e0/24) *(  ((2*x**3 - 3*x) * (1 + x**2)**(1/2))      + 3*np.log( x + ((1 + x**2)**(1/2))    ))


#listnp = [i * 0.2 for i in listnb]      
#listnp = np.asarray(listnp)
#listP =  [i * 1.6022e33 for i in listP] + pre(listnp) 
#listrho =   [i *(1.7827e12)* 931.494 for i in listnb] #+ e(listnp)  

listx = np.asarray(listx)
listP =  [i * 1.6022e33 for i in listP] 
listrho =   [i *(1.7827e12) for i in listrho] 



from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import interp1d

G = 6.674e-8
c = 2.997924562e10


rho = listrho
P = listP

eos =  interp1d(rho,P,fill_value="extrapolate")
inveos =  interp1d(P,rho,fill_value="extrapolate")

def TOV(y, r) :   
    P, m = y[0], y[1]
    rho = inveos
    dPdr =  ( (-G*m*rho(P))/(r**2) ) * (1+( P/(rho(P)*c**2) )) * (1+ ( (4*pi*P*r**3) /(m*c**2) )) *( (1- ((2*G*m)/(r*c**2))  )**(-1) )        
    dmdr = 4.0*pi*r**2*rho(P)
    return np.array([dPdr, dmdr])

def TOVsolve(rhoc):
    r = np.arange(10,5000000,1)
    m = 4.0*pi*r[0]**3*rhoc
    P = eos(rhoc)
    psol = odeint(TOV,[P,m],r)
    return  psol#[:,1]

r = np.arange(10,5000000,1)



#plot M_R curve
rhoc =np.logspace(13.0,16.8,p)
M = np.zeros_like(rhoc)
R = np.zeros_like(rhoc)
i = 0
for i in range(len(rhoc)) :
    P = TOVsolve(rhoc[i])[:,0]
    m = TOVsolve(rhoc[i])[:,1]
    location = np.where(P<1)[0][0]
    R[i] = r[location]
    M[i] = m[location]
    i = i + 1
    

Msun = 1.9e33
plt.plot(R/100000,M/Msun,label='UIX' , linestyle = ':')
#plt.plot(R/100000,M/Msun)
plt.xlabel('R (km)')
plt.ylabel('M/Msun')
#plt.legend(loc='lower left')
plt.legend(loc='upper right')
plt.ylim(0,2.5)
plt.xlim(6,18)

#plt.savefig('filename4562156789.png',dpi=300)
plt.show()
